# %% [markdown]
# # MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# LINE FROM POINT X TO T
xpoints=np.array([1,2])
tpoints=np.array([5,10])

plt.plot(xpoints,tpoints)
plt.show

# %%
# LINEE DRM POINT X TO Y
xpoints=np.array([10,222])
ypoints=np.array([50,100])

plt.plot(xpoints,ypoints)
plt.show

# %%
xpoints=np.array([10,222])
ypoints=np.array([50,100])

plt.plot(xpoints,ypoints,'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([10,222])
ypoints=np.array([50,100])
plt.plot(xpoints,ypoints,'*')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([10,222])
ypoints=np.array([50,100])
plt.plot(ypoints,marker='X')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# xpoints=np.array([10,222,20,4])
ypoints=np.array([50,100,4,55])
plt.plot(ypoints,'*'':r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([10,222,20,4])
ypoints=np.array([50,100,4,55])
plt.plot(xpoints,ypoints,marker='o',ms=10,color='green')
plt.show()

# %%
### You can use the keyword argument markeredgecolor or the shorter mec to 
# set the color of the edge of the markers

xpoints=np.array([10,222,20,4])
ypoints=np.array([50,100,4,55])
plt.plot(xpoints,ypoints,marker='o',ms=10,mec='g')  #  mfc or mec for color 
plt.show()

# %%
xpoints=np.array([10,222,20,4])
ypoints=np.array([50,100,4,55])
plt.plot(xpoints,ypoints,linestyle= 'dashed',marker='o',ms=10,mec='hotpink')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20,mfc='r',mec='b')
plt.show()

# %%
# we can usw the keyword argumennt linewidth or the shorter Lw to change the widthof the line 

# the value is a floting number, in points

ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linewidth='10')
plt.show()

# %%
y1=np.array([3,5,7,9])
y2=np.array([3,5,7,10])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
x=np.array([3,5,7,1,6])
y=np.array([4,6,8,9,3])

plt.plot(x,y,color='r',linewidth =10)

plt.xlabel("AVg PULSE ",fontsize =10,color='red')
plt.ylabel("Caloriw burn", fontsize=11,color='g')

plt.show()

# %%
x=np.array([3,5,7,1,6])
y=np.array([4,6,8,9,3])

plt.plot(x,y,color='r',linewidth =10)

# With Pyplot, you can use the title() function to set a title for the plot
plt.title("Jai mahalkal")        

plt.xlabel("AVg PULSE ",fontsize =10,color='red')
plt.ylabel("Caloriw burn", fontsize=11,color='g')

plt.show()

# %%
x=np.array([3,5,7,1,6])
y=np.array([4,6,8,9,3])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALE 1")


xpoints=np.array([10,222,20,4])
ypoints=np.array([50,100,4,55])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("SALE 2")
# Out:
# Text(0.5, 1.0, 'SALE 2')

# %%
x=np.array([3,5,7,1,6])
y=np.array([4,6,8,9,3])
plt.subplot(2,1,1)
plt.plot(x,y)
plt.title("SALE 1")


xpoints=np.array([10,222,20,4])
ypoints=np.array([50,100,4,55])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.title("SALE 2")
# Out:
# Text(0.5, 1.0, 'SALE 2')

# %%
x=np.array([3,5,7,1,6])
y=np.array([4,6,8,9,3])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.title("SALE 1")


xpoints=np.array([10,222,20,4])
ypoints=np.array([50,100,4,55])
plt.subplot(2,3,2)
plt.plot(x,y)
plt.title("SALE 2")

x=np.array([3,5,7,1,6])
y=np.array([4,6,8,9,3])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.title("SALE 3")


xpoints=np.array([10,222,20,4])
ypoints=np.array([50,100,4,55])
plt.subplot(2,3,4)
plt.plot(x,y)
plt.title("SALE 4")

x=np.array([3,5,7,1,6])
y=np.array([4,6,8,9,3])
plt.subplot(2,3,5)
plt.plot(x,y)
plt.title("SALE 5")


xpoints=np.array([10,222,20,4])
ypoints=np.array([50,100,4,55])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.title("SALE 6")

plt.show()

# %%
### You can use the axis parameter in the grid() function to specify which grid lines to display.

### Legal values are: 'x', 'y', and 'both'. Default value is 'both'
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

# plt.grid(axis = 'x')  
plt.grid(axis = 'y')


plt.show()

# %%
### Set Line Properties for the Grid
### You can also set the line properties of the grid, like this: grid
                 ### (color = 'color', linestyle = 'linestyle', linewidth = number).
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 1.5)

plt.show()

# %%
x=np.array([3,5,7,1,6])
y=np.array([4,6,8,9,3])

plt.scatter(x,y)

# %%
x=np.array([1,3,5,3,4,6,7,5,8,6,9,8])
y=np.array([1,4,5,6,7,8,4,3,6,7,4,7])

plt.scatter(x,y)
plt.show()

# %%
x=np.array([1,3,5,3,4,6,7,5,8,6,9,8])
y=np.array([1,4,5,6,7,8,4,3,6,7,4,7])
plt.scatter(x,y,color='hotpink')

x=np.array([1,3,5,3,4,6,7,5,8,6,9,8])
y=np.array([10,40,50,60,70,80,40,3,60,70,4,70])
plt.scatter(x,y,color='black')

plt.show()

# %%
### With Pyplot, you can use the scatter() function to draw a scatter plot.

## The scatter() function plots one dot for each observation. It needs two arrays of the same length, 
## one for the values of the x-axis, and one for values on the y-axis.
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([23,12,45,23,86,103,87,94,78,77,85,86,12])

plt.scatter(x, y)
plt.show()

# %%
x=np.array([1,3,5,3,4])
y=np.array([10,40,50,60,70])


colors=(["red","yellow","black","blue","red"])
size=([10,200,20,231,40])
plt.scatter(x,y,c=colors,s=size)
plt.show()

# %%
x=np.array([1,3,5,3,4,2,5,4,7,5,10])
y=np.array([10,40,50,60,70,66,33,55,44,88,44])


colors=(["red","yellow","black","blue","red","red","yellow","black","blue","red","hotpink"])

plt.scatter(x,y,c=colors)
plt.colorbar()
plt.show()

# %%
# x=np.array([1,3,5,3,4,2,5,4,7,5,10])
y=np.array([10,40,50,60,70,66,33,55,44,88,44])

plt.pie(y)
plt.show()

# %%
y=np.array([10,20,55,3])
mylabels=["cheeries","appe","toy","buskit"]

plt.pie(y,labels=mylabels)
plt.show()

# %%
y=np.array([10,20,55,3])
mylabels=["cheeries","appe","toy","buskit"]
myexplode=[0,0.95,0.08,3]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %%
# ColorMap
## The Matplotlib module has a number of available colormaps.

### A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.

#### Here is an example of a colormap:

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,87,94,78,77,85,86,13])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
### You can include the colormap in the drawing by including the plt.colorbar() statement
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20,30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8,1,10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
## The barh() takes the keyword argument height to set the height of the bars
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %%
x = np.random.normal(170,10,250)

x
# Out:
# array([171.64624204, 177.73328049, 151.78245693, 159.03096087,
#        168.47944537, 176.92900004, 174.60301155, 158.34797405,
#        181.63036288, 161.04527737, 174.51609555, 173.60244324,
#        156.07867534, 176.79096241, 170.42563165, 176.32787775,
#        170.17881441, 161.56930802, 181.10675327, 180.42920892,
#        175.3764708 , 161.75535659, 156.0377405 , 167.69904855,
#        155.71160334, 181.18122196, 180.297514  , 160.3688462 ,
#        161.45851233, 173.09588419, 156.49315018, 162.7758381 ,
#        189.41777854, 168.5311092 , 155.29316323, 174.17967975,
#        171.08558535, 173.20078389, 169.39957345, 159.17383473,
#        158.52980972, 176.68137406, 183.03420859, 155.16859581,
#        176.97511894, 162.80864319, 176.26775826, 169.97880164,
#        183.30095965, 177.36838029, 186.22499025, 179.62704776,
#        173.11733962, 164.55183593, 164.79020494, 166.85315783,
#        169.14533963, 160.99242943, 169.90014828, 164.23325581,
# ...

# %%
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
y = np.array([10, 135, 25, 15,19])

plt.pie(y)
plt.show()
